# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdulwaliy/OpenCV_Basics/blob/main/OpenCV_Load_Image_and_Crop_Image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title OpenCV Load Image

# import the necessary packages
from matplotlib import pyplot as plt
import argparse
import cv2

# %%
#Read file from google drive
from google.colab import drive
drive.mount('/content/drive')
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Open CV Pictures/open_cv_samples.zip", 'r')
extract_path = "/content/drive/MyDrive/Open CV Pictures"
c = zip_ref.extractall(extract_path)
#zip_ref.close()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def plt_imshow(title, image):
	# convert the image frame BGR to RGB color space and display it
	#image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	plt.imshow(image)
	plt.title(title)
	plt.grid(False)
	plt.show()

# %%
image = cv2.imread("/content/drive/MyDrive/Open CV Pictures/archive/blobs.jpg")
#image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image)
plt.title("pic")
plt.grid(False)
plt.show()

# %%
# @title Getting Pixels

(h,w,c) = image.shape[:3]
print ("The number of rows or height is {}".format(h))
print ("The number of colunms or width is {}".format(w))
print ("The number of channels is {}".format(c))
# Out:
# The number of rows or height is 562
# The number of colunms or width is 603
# The number of channels is 3

# %%
# @title Cropping the Image

(cy,cx) = (h//2, w//2)
crop_image = image[0:h//2, w//2:w] #cropping out the top right corner
plt_imshow("pic", crop_image) #showing the results
